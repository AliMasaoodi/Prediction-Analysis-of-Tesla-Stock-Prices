# %% [markdown]
# # Prediction-Analysis-of-Tesla-Stock-Prices

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas
import numexpr

# %% [markdown]
# # Initial analysis

# %% [markdown]
# ## Data Importing

# %%
tesla = pd.read_csv('C:/Users/Mohammed/Downloads/TSLAStock.csv')
tesla.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0  5/26/2021  607.559998  626.169983  601.500000  619.130005  619.130005
# 1  5/27/2021  620.239990  631.130005  616.210022  630.849976  630.849976
# 2  5/28/2021  628.500000  635.590027  622.380005  625.219971  625.219971
# 3   6/1/2021  627.799988  633.799988  620.549988  623.900024  623.900024
# 4   6/2/2021  620.130005  623.359985  599.140015  605.119995  605.119995
#
#      Volume
# 0  28639300
# 1  26370600
# 2  22737000
# 3  18084900
# 4  23302800

# %% [markdown]
# ## DataFrame statistics

# %%
tesla.set_index('Date')
# Out:
#                  Open        High         Low       Close   Adj Close  \
# Date
# 5/26/2021  607.559998  626.169983  601.500000  619.130005  619.130005
# 5/27/2021  620.239990  631.130005  616.210022  630.849976  630.849976
# 5/28/2021  628.500000  635.590027  622.380005  625.219971  625.219971
# 6/1/2021   627.799988  633.799988  620.549988  623.900024  623.900024
# 6/2/2021   620.130005  623.359985  599.140015  605.119995  605.119995
# ...               ...         ...         ...         ...         ...
# 5/19/2022  707.000000  734.000000  694.109985  709.419983  709.419983
# 5/20/2022  713.989990  721.580017  633.000000  663.900024  663.900024
# 5/23/2022  655.020020  679.960022  638.059998  674.900024  674.900024
# 5/24/2022  653.530029  653.919983  620.570007  628.159973  628.159973
# 5/25/2022  623.849976  669.320007  623.010010  658.799988  658.799988
#
#              Volume
# Date
# 5/26/2021  28639300
# 5/27/2021  26370600
# 5/28/2021  22737000
# 6/1/2021   18084900
# ...

# %% [markdown]
# ## Stock data line chart

# %%
plt.figure(figsize=(15, 7))
tesla['Close'].plot()
plt.show()

# %% [markdown]
# ## Price difference

# %%
tesla['PriceDiff'] = tesla['Close'].shift(-1) - tesla['Close']
print(tesla['PriceDiff'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 tesla['PriceDiff'] = tesla['Close'].shift(-1) - tesla['Close']
#       2 print(tesla['PriceDiff'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:65, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      61             return NotImplemented
#      63 other = item_from_zerodim(other)
# ---> 65 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:97, in OpsMixin.__sub__(self, other)
#      95 @unpack_zerodim_and_defer("__sub__")
#      96 def __sub__(self, other):
# ---> 97     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4998, in Series._arith_method(self, other, op)
#    4996 lvalues = extract_array(self, extract_numpy=True)
# ...

# %% [markdown]
# ## Daily Stock return

# %%
tesla['Return'] = tesla['PriceDiff'] /tesla['Close']
print(tesla['Return'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3080, in Index.get_loc(self, key, method, tolerance)
#    3079 try:
# -> 3080     return self._engine.get_loc(casted_key)
#    3081 except KeyError as err:
#
# File pandas\_libs\index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:4554, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:4562, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PriceDiff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ...

# %% [markdown]
# # Rolling Window Analysis

# %%
tesla['ma50'] = tesla['Close'].rolling(50).mean()
#plot the moving average
plt.figure(figsize=(15, 8))
tesla['ma50'].plot(label='MA50')
tesla['Close'].plot(label='Close')
plt.legend()
plt.show()
